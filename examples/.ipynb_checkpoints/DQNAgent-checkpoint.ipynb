# %%
"""
In this example we demonstrate how to implement a DQN agent and
train it to trade optimally on a periodic price signal.
Training time is short and results are unstable.
Do not hesitate to run several times and/or tweak parameters to get better results.
Inspired from https://github.com/keon/deep-q-learning
"""
import random

import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam
from tgym.envs import SpreadTrading
# %matplotlib inline

# %%
class DQNAgent:
    def __init__(self,
                 state_size,
                 action_size,
                 episodes,
                 episode_length,
                 memory_size=2000,
                 train_interval=100,
                 gamma=0.95,
                 learning_rate=0.001,
                 batch_size=64,
                 epsilon_min=0.01
                 ):
        self.state_size = state_size
        self.action_size = action_size
        self.memory_size = memory_size
        self.memory = [None] * memory_size
        self.gamma = gamma
        self.epsilon = 1.0
        self.epsilon_min = epsilon_min
        self.epsilon_decrement = (self.epsilon - epsilon_min)\
            * train_interval / (episodes * episode_length)  # linear decrease rate
        self.learning_rate = learning_rate
        self.train_interval = train_interval
        self.batch_size = batch_size
        self.brain = self._build_brain()
        self.i = 0

    def _build_brain(self):
        """Build the agent's brain
        """
        brain = Sequential()
        neurons_per_layer = 24
        activation = "relu"
        brain.add(Dense(neurons_per_layer,
                        input_dim=self.state_size,
                        activation=activation))
        brain.add(Dense(neurons_per_layer, activation=activation))
        brain.add(Dense(self.action_size, activation='linear'))
        brain.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return brain

    def act(self, state):
        """Acting Policy of the DQNAgent
        """
        action = np.zeros(self.action_size)
        if np.random.rand() <= self.epsilon:
            action[random.randrange(self.action_size)] = 1
        else:
            state = state.reshape(1, self.state_size)
            act_values = self.brain.predict(state)
            action[np.argmax(act_values[0])] = 1
        return action

    def observe(self, state, action, reward, next_state, done, warming_up=False):
        """Memory Management and training of the agent
        """
        self.i = (self.i + 1) % self.memory_size
        self.memory[self.i] = (state, action, reward, next_state, done)
        if (not warming_up) and (self.i % self.train_interval) == 0:
            if self.epsilon > self.epsilon_min:
                self.epsilon -= self.epsilon_decrement
            state, action, reward, next_state, done = self._get_batches()
            reward += (self.gamma
                       * np.logical_not(done)
                       * np.amax(self.brain.predict(next_state),
                                 axis=1))
            q_target = self.brain.predict(state)
            print "state: ", state
            print "action[0]: ", action[0]
            print "action[1]: ", action[1]
            print "q_target: ", q_target[action[0]]
            print "q_target: ", q_target[action[0]]
            print "reward: ", reward
            
            q_target[action[0], action[1]] = reward
            return self.brain.fit(state, q_target,
                                  batch_size=self.batch_size,
                                  epochs=1,
                                  verbose=False)

    def _get_batches(self):
        """Selecting a batch of memory
           Split it into categorical subbatches
           Process action_batch into a position vector
        """
        batch = np.array(random.sample(self.memory, self.batch_size))
        state_batch = np.concatenate(batch[:, 0])\
            .reshape(self.batch_size, self.state_size)
        action_batch = np.concatenate(batch[:, 1])\
            .reshape(self.batch_size, self.action_size)
        reward_batch = batch[:, 2]
        next_state_batch = np.concatenate(batch[:, 3])\
            .reshape(self.batch_size, self.state_size)
        done_batch = batch[:, 4]
        # action processing
        action_batch = np.where(action_batch == 1)
        return state_batch, action_batch, reward_batch, next_state_batch, done_batch

# %%
import matplotlib.pyplot as plt
from tgym.envs import SpreadTrading
from tgym.gens.deterministic import WavySignal
# Instantiating the environmnent
generator = WavySignal(period_1=25, period_2=50, epsilon=-0.5)
episodes = 50
episode_length = 400
trading_fee = .2
time_fee = 0
history_length = 2
environment = SpreadTrading(spread_coefficients=[1],
                                data_generator=generator,
                                trading_fee=trading_fee,
                                time_fee=time_fee,
                                history_length=history_length)

# %%
environment.__dict__
# Out:
# {'_action': array([1, 0, 0]),
#  '_data_generator': <tgym.gens.deterministic.WavySignal at 0x1226994d0>,
#  '_entry_price': 0,
#  '_exit_price': 0,
#  '_first_render': True,
#  '_game_length': 1000,
#  '_history_length': 2,
#  '_iteration': 0,
#  '_position': array([1, 0, 0]),
#  '_price_range': 0,
#  '_prices_history': [(0.31036821396513004, 0.31036821396513004),
#   (0.5982855675701456, 0.5982855675701456)],
#  '_spread_coefficients': [1],
#  '_time_fee': 0,
#  '_total_pnl': 0,
#  '_total_reward': 0,
#  '_trading_fee': 0.2,
#  'n_actions': 3,
#  'state_shape': (8,)}

# %%
state = environment.reset()
# Instantiating the agent
memory_size = 3000
state_size = len(state)
gamma = 0.96
epsilon_min = 0.01
batch_size = 64
action_size = len(SpreadTrading._actions)
train_interval = 10
learning_rate = 0.001
agent = DQNAgent(state_size=state_size,
                     action_size=action_size,
                     memory_size=memory_size,
                     episodes=episodes,
                     episode_length=episode_length,
                     train_interval=train_interval,
                     gamma=gamma,
                     learning_rate=learning_rate,
                     batch_size=batch_size,
                     epsilon_min=epsilon_min)
# Warming up the agent
for _ in range(memory_size):
        action = agent.act(state)
        next_state, reward, done, _ = environment.step(action)
        agent.observe(state, action, reward, next_state, done, warming_up=True)
# Training the agent
for ep in range(episodes):
    state = environment.reset()
    rew = 0
    for _ in range(episode_length):
        action = agent.act(state)
        next_state, reward, done, _ = environment.step(action)
        loss = agent.observe(state, action, reward, next_state, done)
        state = next_state
        rew += reward
    print("Ep:" + str(ep)
           + "| rew:" + str(round(rew, 2))
           + "| eps:" + str(round(agent.epsilon, 2))
           + "| loss:" + str(round(loss.history["loss"][0], 4)))
# Out:
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:0| rew:-42.09| eps:0.98| loss:0.0138
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:1| rew:-44.86| eps:0.96| loss:0.1057
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:2| rew:-45.26| eps:0.94| loss:0.0599
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:3| rew:-64.9| eps:0.92| loss:0.0461
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:4| rew:-53.07| eps:0.9| loss:0.0572
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:5| rew:-49.59| eps:0.88| loss:0.041
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:6| rew:-41.0| eps:0.86| loss:0.0252
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:7| rew:-40.77| eps:0.84| loss:0.0442
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:8| rew:-52.98| eps:0.82| loss:0.0436
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:9| rew:-66.83| eps:0.8| loss:0.0203
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:10| rew:-53.65| eps:0.78| loss:0.0143
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:11| rew:-36.11| eps:0.76| loss:0.013
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:12| rew:-37.75| eps:0.74| loss:0.0182
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:13| rew:-46.49| eps:0.72| loss:0.0412
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:14| rew:-35.22| eps:0.7| loss:0.0828
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:15| rew:-49.44| eps:0.68| loss:0.071
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# ...
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:44| rew:26.62| eps:0.11| loss:0.0057
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:45| rew:51.2| eps:0.09| loss:0.0069
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:46| rew:52.07| eps:0.07| loss:0.0049
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:47| rew:52.11| eps:0.05| loss:0.0053
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:48| rew:56.71| eps:0.03| loss:0.0068
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# state:  (64, 8)
# action:  (2, 64)
# action [0]:  (64,)
# action [1]:  (64,)
# Ep:49| rew:52.79| eps:0.01| loss:0.0042

# %%
# Running the agent
done = False
state = environment.reset()
while not done:
    action = agent.act(state)
    state, _, done, info = environment.step(action)
    if 'status' in info and info['status'] == 'Closed plot':
        done = True
    else:
        environment.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e37da95bdba0> in <module>()
#       8         done = True
#       9     else:
# ---> 10         environment.render()
#
# /Users/matthewdixon/anaconda/lib/python2.7/site-packages/tgym/envs/trading.pyc in render(self, savefig, filename)
#     208                      'Position: ' + ['flat', 'long', 'short'][list(self._position).index(1)] + ' ~ ' +
#     209                      'Entry Price: ' + "%.2f" % self._entry_price)
# --> 210         self._f.tight_layout()
#     211         plt.xticks(range(self._iteration)[::5])
#     212         plt.xlim([max(0, self._iteration - 80.5), self._iteration + 0.5])
#
# /Users/matthewdixon/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    1753                                          rect=rect)
#    1754
# -> 1755         self.subplots_adjust(**kwargs)
#    1756
#    1757
#
# /Users/matthewdixon/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in subplots_adjust(self, *args, **kwargs)
#    1631                     ax.set_position(ax._sharey.figbox)
#    1632             else:
# -> 1633                 ax.update_params()
#    1634                 ax.set_position(ax.figbox)
#    1635         self.stale = True
#
# /Users/matthewdixon/anaconda/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in update_params(self)
#     112         self.figbox, self.rowNum, self.colNum, self.numRows, self.numCols = \
#     113             self.get_subplotspec().get_position(self.figure,
# --> 114                                                 return_all=True)
#     115
#     116     def is_first_col(self):
#
# /Users/matthewdixon/anaconda/lib/python2.7/site-packages/matplotlib/gridspec.pyc in get_position(self, fig, return_all)
#     427
#     428         figBottoms, figTops, figLefts, figRights = \
# --> 429                     gridspec.get_grid_positions(fig)
#     430
#     431
#
# /Users/matthewdixon/anaconda/lib/python2.7/site-packages/matplotlib/gridspec.pyc in get_grid_positions(self, fig)
#      88         nrows, ncols = self.get_geometry()
#      89
# ---> 90         subplot_params = self.get_subplot_params(fig)
#      91         left = subplot_params.left
#      92         right = subplot_params.right
#
# /Users/matthewdixon/anaconda/lib/python2.7/site-packages/matplotlib/gridspec.pyc in get_subplot_params(self, fig)
#     270             subplotpars = SubplotParams(**kw)
#     271         else:
# --> 272             subplotpars = copy.copy(fig.subplotpars)
#     273
#     274         update_kw = dict([(k, getattr(self, k)) for k in self._AllowedKeys])
#
# /Users/matthewdixon/anaconda/lib/python2.7/copy.pyc in copy(x)
#      86         reductor = getattr(x, "__reduce_ex__", None)
#      87         if reductor:
# ---> 88             rv = reductor(2)
#      89         else:
#      90             reductor = getattr(x, "__reduce__", None)
#
# KeyboardInterrupt:
